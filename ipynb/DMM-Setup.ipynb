# %% [markdown]
# ## Overview
# This notebook walks through creating, setting up and training a Deep Markov Model on a synthetic dataset

# %%
#General Purpose Imports
import numpy as np
import glob, os, sys, time
sys.path.append('../')
from utils.misc import getConfigFile, readPickle, displayTime

# %% [markdown]
# ## A] Data
# * The polyphonic music code (which can be run from the `expt` folder) represents an example of running on binary data
# * There is code to create a synthetic dataset in `dmm_data/load.py`, we will load that dataset here (it will be created the first time this function is called)

# %%
#Import load function to load synthetic data
from dmm_data.load import load
dataset = load('synthetic')
print type(dataset), dataset.keys()
# Out:
# Loading linear matrices
# Loading linear matrices
# Reloading...
# Read  1  objects
# <type 'dict'> ['test', 'dim_observations', 'train', 'valid', 'data_type']

# %% [markdown]
# ### a) Dataset format
# The dataset's are expected to be in a specific format:
# * The type of the variable `dataset` is `dict`
# * The keys of this dataset correspond to parameters used by the model as well as raw data
# * `dim_observations` is of type `int` and it corresponds to the dimensionality of the raw data at each point in time
# * `data_type` can be `binary` or `real`
# * `train`,`valid` and `test` are dictionaries that house the pre-split data. `dataset['train']` contains three items:
#     * `dataset['train']['tensor']` is a 3D tensor where the dimensions correspond to `Nsamples x T x dim_observations`
#     * `dataset['train']['mask']` is a 2D matrix where the dimensions correspond to `Nsamples x T`. Each entry in this matrix corresponds to whether a sample was observed at that point in time. This is used internally by the model to model variable length sequences.
#     * `dataset['train']['tensor_Z']` is not used by the model. It corresponds to the states of the **true** underlying latent variables that created this data

# %%
print 'Dimensionality of the observations: ', dataset['dim_observations']
print 'Data type of features:', dataset['data_type']
for dtype in ['train','valid','test']:
    print 'dtype: ',dtype, ' type(dataset[dtype]): ',type(dataset[dtype])
    print [(k,type(dataset[dtype][k]), dataset[dtype][k].shape) for k in dataset[dtype]]
    print '--------\n'
# Out:
# Dimensionality of the observations:  3
# Data type of features: real
# dtype:  train  type(dataset[dtype]):  <type 'dict'>
# [('tensor_Z', <type 'numpy.ndarray'>, (10000, 10, 3)), ('mask', <type 'numpy.ndarray'>, (10000, 10)), ('tensor', <type 'numpy.ndarray'>, (10000, 10, 3))]
# --------
#
# dtype:  valid  type(dataset[dtype]):  <type 'dict'>
# [('tensor_Z', <type 'numpy.ndarray'>, (1000, 10, 3)), ('mask', <type 'numpy.ndarray'>, (1000, 10)), ('tensor', <type 'numpy.ndarray'>, (1000, 10, 3))]
# --------
#
# dtype:  test  type(dataset[dtype]):  <type 'dict'>
# [('tensor_Z', <type 'numpy.ndarray'>, (1000, 10, 3)), ('mask', <type 'numpy.ndarray'>, (1000, 10)), ('tensor', <type 'numpy.ndarray'>, (1000, 10, 3))]
# --------

# %% [markdown]
# ### b) Creating your own dataset
# * When creating your own data, it should have the following structure:
#     * type: dict
#         * `dim_observations`: int
#         * `data_type`: `binary` or `real`
#         * `train`, `valid`, `test` must be dictionaries with the following keys:
#             * `tensor` : Raw data as a 3D tensor with dimensions `Nsamples x T x dim_observations`
#             * `mask`   : Mask for the raw data as a 2D matrix with dimensions `Nsamples x T`
# * Now that we have the dataset in the desired format, lets look at setting up the model, we'll first load the necessary files to build the model

# %%
start_time = time.time()
from   model_th.dmm import DMM
import model_th.learning as DMM_learn
import model_th.evaluate as DMM_evaluate
displayTime('importing DMM',start_time, time.time())
# Out:
# 		< importing DMM > took  0.860870838165   seconds

# %% [markdown]
# ## B] Model Hyperparameters
# * To setup the model, we need to specify the hyperparameters
# * Normally, if you were running from a script, you would run the following: `from parse_args import params` (e.g `expt/train.py` within the script.
# * This lets you specify hyperparameters for the model via the command line. See the shell scripts in the folder `expt/` for an example of this.
# * Since we're in Ipython, we'll reload a saved version of `params` and see what the default values currently are. To know more about how the choices of hyperparameters affect the model, you can run `python parse_args.py -h` in the main directory.
# * The `unique_id` is created based on the default parameters or those specified via the commend line.
# * The parameters (`data_type` and `dim_observations`) of the dataset need to be incorporated into `params` for the model to be able to setup the weights appropriately

# %%
params = readPickle('../default.pkl')[0]
for k in params:
    print k, '\t',params[k]
params['data_type'] = dataset['data_type']
params['dim_observations'] = dataset['dim_observations']
# Out:
# Read  1  objects
# dataset 	mm
# epochs 	2000
# seed 	1
# init_weight 	0.1
# dim_stochastic 	100
# expt_name 	uid
# reg_value 	0.05
# reloadFile 	./NOSUCHFILE
# reg_spec 	_
# dim_hidden 	200
# lr 	0.0008
# reg_type 	l2
# init_scheme 	uniform
# optimizer 	adam
# use_generative_prior 	approx
# maxout_stride 	4
# batch_size 	20
# savedir 	./chkpt
# forget_bias 	-5.0
# inference_model 	R
# emission_layers 	2
# savefreq 	10
# rnn_cell 	lstm
# rnn_size 	600
# paramFile 	./NOSUCHFILE
# nonlinearity 	relu
# rnn_dropout 	0.1
# transition_layers 	2
# anneal_rate 	2.0
# debug 	False
# validate_only 	False
# transition_type 	mlp
# unique_id 	DMM_lr-0_0008-dh-200-ds-100-nl-relu-bs-20-ep-2000-rs-600-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid
# leaky_param 	0.0

# %% [markdown]
# ## C] Building the DMM

# %%
#The dataset is small, lets change some of the default parameters and the unique ID
params['dim_stochastic'] = 2
params['dim_hidden']     = 40
params['rnn_size']       = 80
params['epochs']         = 40
params['batch_size']     = 200
params['unique_id'] = params['unique_id'].replace('ds-100','ds-2').replace('dh-200','dh-40').replace('rs-600','rs-80')
params['unique_id'] = params['unique_id'].replace('ep-2000','ep-40').replace('bs-20','bs-200')

#Create a temporary directory to save checkpoints
params['savedir']   = params['savedir']+'-ipython/'
os.system('mkdir -p '+params['savedir'])

#Specify the file where `params` corresponding for this choice of model and data will be saved
pfile= params['savedir']+'/'+params['unique_id']+'-config.pkl'

print 'Checkpoint prefix: ', pfile
dmm  = DMM(params, paramFile = pfile)
# Out:
# Checkpoint prefix:  ./chkpt-ipython//DMM_lr-0_0008-dh-40-ds-2-nl-relu-bs-200-ep-40-rs-80-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid-config.pkl
# 	<<Sampling biases for LSTM from exponential distribution>>
# 	<<Nparameters: 56334>>
# 	<<WARNING: lr will not differentiated with respect to>>
# 	<<WARNING: anneal will not differentiated with respect to>>
# 	<<WARNING: update_ctr will not differentiated with respect to>>
# 	<<Anneal = 1 in 2.0 param. updates>>
# 	<<Building with RNN dropout:0.1>>
# 	<<In _LSTM_RNN_layer with dropout 0.1000>>
# 	<<Modifying : [q_W_input_0,q_b_input_0,W_lstm_r,b_lstm_r,U_lstm_r,q_W_st,q_b_st,q_W_mu,q_b_mu,q_W_cov,q_b_cov,p_trans_W_0,p_trans_b_0,p_trans_W_1,p_trans_b_1,p_trans_W_mu,p_trans_b_mu,p_trans_W_cov,p_trans_b_cov,p_emis_W_0,p_emis_b_0,p_emis_W_1,p_emis_b_1,p_emis_W_out,p_emis_b_out]>>
# << Reg:(l2) Reg. Val:(0.05) Reg. Spec.:(_)>>
# <<<<<< Adding l2 regularization for q_W_input_0 >>>>>>
# <<<<<< Adding l2 regularization for q_b_input_0 >>>>>>
# <<<<<< Adding l2 regularization for W_lstm_r >>>>>>
# <<<<<< Adding l2 regularization for b_lstm_r >>>>>>
# <<<<<< Adding l2 regularization for U_lstm_r >>>>>>
# <<<<<< Adding l2 regularization for q_W_st >>>>>>
# <<<<<< Adding l2 regularization for q_b_st >>>>>>
# <<<<<< Adding l2 regularization for q_W_mu >>>>>>
# <<<<<< Adding l2 regularization for q_b_mu >>>>>>
# <<<<<< Adding l2 regularization for q_W_cov >>>>>>
# <<<<<< Adding l2 regularization for q_b_cov >>>>>>
# <<<<<< Adding l2 regularization for p_trans_W_0 >>>>>>
# <<<<<< Adding l2 regularization for p_trans_b_0 >>>>>>
# <<<<<< Adding l2 regularization for p_trans_W_1 >>>>>>
# <<<<<< Adding l2 regularization for p_trans_b_1 >>>>>>
# <<<<<< Adding l2 regularization for p_trans_W_mu >>>>>>
# <<<<<< Adding l2 regularization for p_trans_b_mu >>>>>>
# <<<<<< Adding l2 regularization for p_trans_W_cov >>>>>>
# <<<<<< Adding l2 regularization for p_trans_b_cov >>>>>>
# <<<<<< Adding l2 regularization for p_emis_W_0 >>>>>>
# <<<<<< Adding l2 regularization for p_emis_b_0 >>>>>>
# <<<<<< Adding l2 regularization for p_emis_W_1 >>>>>>
# <<<<<< Adding l2 regularization for p_emis_b_1 >>>>>>
# <<<<<< Adding l2 regularization for p_emis_W_out >>>>>>
# <<<<<< Adding l2 regularization for p_emis_b_out >>>>>>
# <<<<<< Normalizing Gradients to have norm ( 1.0 ) >>>>>>
# 	<<0 other updates>>
# 	<<Building with RNN dropout:0.0>>
# 	<<In _LSTM_RNN_layer with dropout 0.0000>>
# 	<<Completed DMM setup>>
# 	<<_buildModel took : 9.1042 seconds>>

# %% [markdown]
# ## D] Parameter Estimation

# %%
#savef specifies the prefix for the checkpoints - we'll use the same save directory as before 
savef    = os.path.join(params['savedir'],params['unique_id'])
savedata = DMM_learn.learn(dmm, dataset['train'], epoch_start =0 ,
                                epoch_end = params['epochs'],
                                batch_size = 200,
                                savefreq   = params['savefreq'],
                                savefile   = savef,
                                dataset_eval=dataset['valid'],
                                shuffle    = True )
# Out:
# 	<<Original dim: [3 5 3],[3 5]>>
# 	<<New dim: [10000    10     3],[10000    10]>>
# 	<<Bnum: 0, Batch Bound: 27.2308, |w|: 34.3823, |dw|: 1.0000, |w_opt|: 0.0000>>
# 	<<-veCLL:54461.2360, KL:34.9538, anneal:0.0100>>
# 	<<Bnum: 10, Batch Bound: 26.6092, |w|: 34.0214, |dw|: 1.0000, |w_opt|: 0.6507>>
# 	<<-veCLL:53199.3876, KL:19.0197, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 26.2080, |w|: 33.6336, |dw|: 1.0000, |w_opt|: 0.8759>>
# 	<<-veCLL:52388.2278, KL:27.8222, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 25.5067, |w|: 33.2729, |dw|: 1.0000, |w_opt|: 0.9516>>
# 	<<-veCLL:50922.5333, KL:90.9376, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 23.4843, |w|: 33.0148, |dw|: 1.0000, |w_opt|: 0.9758>>
# 	<<-veCLL:46639.7084, KL:328.8080, anneal:1.0000>>
# 	<<(Ep 0) Bound: 25.3746 [Took 31.1471 seconds] >>
# 	<<Saving at epoch 0>>
# 	<<Saved model (./chkpt-ipython/DMM_lr-0_0008-dh-40-ds-2-nl-relu-bs-200-ep-40-rs-80-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid-EP0-params)
# 		 opt (./chkpt-ipython/DMM_lr-0_0008-dh-40-ds-2-nl-relu-bs-200-ep-40-rs-80-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid-EP0-optParams) weights>>
# 	<<Original dim: [10000    10     3],[10000    10]>>
# 	<<New dim: [1000   10    3],[1000   10]>>
# 	<<(Evaluate) Validation Bound: 21.7737 [Took 0.4903 seconds]>>
# 	<<Original dim: [1000   10    3],[1000   10]>>
# 	<<New dim: [10000    10     3],[10000    10]>>
# 	<<Bnum: 0, Batch Bound: 21.7500, |w|: 32.8990, |dw|: 1.0000, |w_opt|: 0.9779>>
# 	<<-veCLL:42498.3666, KL:1001.6501, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 18.1202, |w|: 32.9593, |dw|: 1.0000, |w_opt|: 0.9700>>
# 	<<-veCLL:34058.2622, KL:2182.1279, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 13.1453, |w|: 33.1640, |dw|: 1.0000, |w_opt|: 0.9648>>
# 	<<-veCLL:23166.1868, KL:3124.3364, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 9.8278, |w|: 33.3261, |dw|: 1.0000, |w_opt|: 0.9586>>
# 	<<-veCLL:17548.0917, KL:2107.5034, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 9.0338, |w|: 33.1978, |dw|: 1.0000, |w_opt|: 0.8181>>
# 	<<-veCLL:17074.5892, KL:992.9523, anneal:1.0000>>
# 	<<(Ep 1) Bound: 13.1309 [Took 30.9733 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.8456, |w|: 32.8695, |dw|: 1.0000, |w_opt|: 0.6439>>
# 	<<-veCLL:16932.1652, KL:758.9745, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.7399, |w|: 32.5070, |dw|: 1.0000, |w_opt|: 0.7350>>
# 	<<-veCLL:16776.5999, KL:703.2793, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.6359, |w|: 32.1860, |dw|: 1.0000, |w_opt|: 0.7429>>
# 	<<-veCLL:16683.0759, KL:588.6587, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.5780, |w|: 31.8969, |dw|: 1.0000, |w_opt|: 0.7538>>
# 	<<-veCLL:16678.5735, KL:477.5127, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4976, |w|: 31.6158, |dw|: 1.0000, |w_opt|: 0.7143>>
# 	<<-veCLL:16605.9090, KL:389.2594, anneal:1.0000>>
# 	<<(Ep 2) Bound: 8.6254 [Took 31.2753 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.5327, |w|: 31.3255, |dw|: 1.0000, |w_opt|: 0.7329>>
# 	<<-veCLL:16791.0065, KL:274.3846, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4751, |w|: 31.0670, |dw|: 1.0000, |w_opt|: 0.6509>>
# 	<<-veCLL:16755.2574, KL:194.8431, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4569, |w|: 30.7898, |dw|: 1.0000, |w_opt|: 0.6146>>
# 	<<-veCLL:16803.4309, KL:110.2961, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4527, |w|: 30.5088, |dw|: 1.0000, |w_opt|: 0.4502>>
# 	<<-veCLL:16841.0682, KL:64.3525, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3888, |w|: 30.2443, |dw|: 1.0000, |w_opt|: 0.2624>>
# 	<<-veCLL:16739.0412, KL:38.5805, anneal:1.0000>>
# 	<<(Ep 3) Bound: 8.4458 [Took 30.4859 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4654, |w|: 29.9851, |dw|: 1.0000, |w_opt|: 0.2495>>
# 	<<-veCLL:16897.9594, KL:32.8898, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4500, |w|: 29.7317, |dw|: 1.0000, |w_opt|: 0.2724>>
# 	<<-veCLL:16874.8843, KL:25.1251, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.3683, |w|: 29.5233, |dw|: 1.0000, |w_opt|: 0.2131>>
# 	<<-veCLL:16716.7644, KL:19.8221, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4041, |w|: 29.3341, |dw|: 1.0000, |w_opt|: 0.2222>>
# 	<<-veCLL:16791.2582, KL:16.9450, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4447, |w|: 29.1488, |dw|: 1.0000, |w_opt|: 0.2009>>
# 	<<-veCLL:16871.2104, KL:18.2889, anneal:1.0000>>
# 	<<(Ep 4) Bound: 8.4233 [Took 30.8350 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.3789, |w|: 28.9680, |dw|: 1.0000, |w_opt|: 0.2657>>
# 	<<-veCLL:16741.8300, KL:15.9651, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4246, |w|: 28.7858, |dw|: 1.0000, |w_opt|: 0.1711>>
# 	<<-veCLL:16834.5043, KL:14.6543, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.3949, |w|: 28.5937, |dw|: 1.0000, |w_opt|: 0.2021>>
# 	<<-veCLL:16777.7269, KL:12.0805, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4157, |w|: 28.4119, |dw|: 1.0000, |w_opt|: 0.2463>>
# 	<<-veCLL:16821.3689, KL:10.0575, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4512, |w|: 28.2325, |dw|: 1.0000, |w_opt|: 0.1533>>
# 	<<-veCLL:16892.8267, KL:9.5627, anneal:1.0000>>
# 	<<(Ep 5) Bound: 8.4211 [Took 30.6991 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4121, |w|: 28.0576, |dw|: 1.0000, |w_opt|: 0.1669>>
# 	<<-veCLL:16815.0915, KL:9.1091, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4297, |w|: 27.8813, |dw|: 1.0000, |w_opt|: 0.2453>>
# 	<<-veCLL:16850.4042, KL:8.9063, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4533, |w|: 27.6897, |dw|: 1.0000, |w_opt|: 0.2189>>
# 	<<-veCLL:16897.4858, KL:9.0467, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4152, |w|: 27.4824, |dw|: 1.0000, |w_opt|: 0.2016>>
# 	<<-veCLL:16822.0392, KL:8.3921, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4215, |w|: 27.2975, |dw|: 1.0000, |w_opt|: 0.2780>>
# 	<<-veCLL:16834.2847, KL:8.7652, anneal:1.0000>>
# 	<<(Ep 6) Bound: 8.4205 [Took 30.0747 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.3747, |w|: 27.1437, |dw|: 1.0000, |w_opt|: 0.2677>>
# 	<<-veCLL:16740.9790, KL:8.4073, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4501, |w|: 27.0030, |dw|: 1.0000, |w_opt|: 0.3130>>
# 	<<-veCLL:16892.4573, KL:7.8368, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4432, |w|: 26.8657, |dw|: 1.0000, |w_opt|: 0.1498>>
# 	<<-veCLL:16878.5418, KL:7.8781, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3972, |w|: 26.7108, |dw|: 1.0000, |w_opt|: 0.2010>>
# 	<<-veCLL:16787.5070, KL:6.9737, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4565, |w|: 26.5687, |dw|: 1.0000, |w_opt|: 0.2137>>
# 	<<-veCLL:16903.4538, KL:9.5227, anneal:1.0000>>
# 	<<(Ep 7) Bound: 8.4198 [Took 30.3953 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4524, |w|: 26.4330, |dw|: 1.0000, |w_opt|: 0.2233>>
# 	<<-veCLL:16894.0092, KL:10.7532, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.3828, |w|: 26.3078, |dw|: 1.0000, |w_opt|: 0.1364>>
# 	<<-veCLL:16754.5491, KL:10.9807, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4415, |w|: 26.1645, |dw|: 1.0000, |w_opt|: 0.1039>>
# 	<<-veCLL:16872.1548, KL:10.8760, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4172, |w|: 26.0166, |dw|: 1.0000, |w_opt|: 0.2253>>
# 	<<-veCLL:16826.7269, KL:7.5860, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4096, |w|: 25.8873, |dw|: 1.0000, |w_opt|: 0.2128>>
# 	<<-veCLL:16812.3235, KL:6.9763, anneal:1.0000>>
# 	<<(Ep 8) Bound: 8.4204 [Took 29.9628 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4344, |w|: 25.7571, |dw|: 1.0000, |w_opt|: 0.1651>>
# 	<<-veCLL:16863.0359, KL:5.7445, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.3921, |w|: 25.6511, |dw|: 1.0000, |w_opt|: 0.2469>>
# 	<<-veCLL:16779.5458, KL:4.5982, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4168, |w|: 25.5335, |dw|: 1.0000, |w_opt|: 0.2815>>
# 	<<-veCLL:16828.9438, KL:4.5726, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4607, |w|: 25.4032, |dw|: 1.0000, |w_opt|: 0.1147>>
# 	<<-veCLL:16917.9235, KL:3.5465, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4058, |w|: 25.2820, |dw|: 1.0000, |w_opt|: 0.1250>>
# 	<<-veCLL:16808.6333, KL:3.0213, anneal:1.0000>>
# 	<<(Ep 9) Bound: 8.4200 [Took 31.0292 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4574, |w|: 25.1518, |dw|: 1.0000, |w_opt|: 0.2090>>
# 	<<-veCLL:16911.7073, KL:3.1162, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4204, |w|: 25.0292, |dw|: 1.0000, |w_opt|: 0.2076>>
# 	<<-veCLL:16837.9733, KL:2.9100, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4323, |w|: 24.9121, |dw|: 1.0000, |w_opt|: 0.2127>>
# 	<<-veCLL:16861.7138, KL:2.8424, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4525, |w|: 24.7903, |dw|: 1.0000, |w_opt|: 0.1459>>
# 	<<-veCLL:16901.4297, KL:3.5419, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4163, |w|: 24.6854, |dw|: 1.0000, |w_opt|: 0.1816>>
# 	<<-veCLL:16829.1592, KL:3.4566, anneal:1.0000>>
# 	<<(Ep 10) Bound: 8.4199 [Took 31.4846 seconds] >>
# 	<<Saving at epoch 10>>
# 	<<Saved model (./chkpt-ipython/DMM_lr-0_0008-dh-40-ds-2-nl-relu-bs-200-ep-40-rs-80-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid-EP10-params)
# 		 opt (./chkpt-ipython/DMM_lr-0_0008-dh-40-ds-2-nl-relu-bs-200-ep-40-rs-80-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid-EP10-optParams) weights>>
# 	<<Original dim: [10000    10     3],[10000    10]>>
# 	<<New dim: [1000   10    3],[1000   10]>>
# 	<<(Evaluate) Validation Bound: 8.4420 [Took 0.3462 seconds]>>
# 	<<Original dim: [1000   10    3],[1000   10]>>
# 	<<New dim: [10000    10     3],[10000    10]>>
# 	<<Bnum: 0, Batch Bound: 8.4367, |w|: 24.5764, |dw|: 1.0000, |w_opt|: 0.1230>>
# 	<<-veCLL:16870.9188, KL:2.4503, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4283, |w|: 24.4709, |dw|: 1.0000, |w_opt|: 0.1653>>
# 	<<-veCLL:16853.9246, KL:2.6411, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4260, |w|: 24.3599, |dw|: 1.0000, |w_opt|: 0.2749>>
# 	<<-veCLL:16849.3038, KL:2.7523, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4374, |w|: 24.2468, |dw|: 1.0000, |w_opt|: 0.2263>>
# 	<<-veCLL:16871.4822, KL:3.2488, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4390, |w|: 24.1515, |dw|: 1.0000, |w_opt|: 0.1474>>
# 	<<-veCLL:16874.6950, KL:3.3280, anneal:1.0000>>
# 	<<(Ep 11) Bound: 8.4193 [Took 29.8653 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.3845, |w|: 24.0531, |dw|: 1.0000, |w_opt|: 0.1699>>
# 	<<-veCLL:16765.9462, KL:3.0114, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4135, |w|: 23.9514, |dw|: 1.0000, |w_opt|: 0.2132>>
# 	<<-veCLL:16824.4014, KL:2.6702, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4264, |w|: 23.8491, |dw|: 1.0000, |w_opt|: 0.2356>>
# 	<<-veCLL:16850.4590, KL:2.3136, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4055, |w|: 23.7452, |dw|: 1.0000, |w_opt|: 0.1593>>
# 	<<-veCLL:16808.8487, KL:2.1352, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3910, |w|: 23.6500, |dw|: 1.0000, |w_opt|: 0.3114>>
# 	<<-veCLL:16779.8193, KL:2.1398, anneal:1.0000>>
# 	<<(Ep 12) Bound: 8.4198 [Took 29.8886 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4280, |w|: 23.5561, |dw|: 1.0000, |w_opt|: 0.1860>>
# 	<<-veCLL:16854.0992, KL:1.9759, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4302, |w|: 23.4660, |dw|: 1.0000, |w_opt|: 0.1691>>
# 	<<-veCLL:16858.2813, KL:2.0897, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.3938, |w|: 23.3626, |dw|: 1.0000, |w_opt|: 0.1897>>
# 	<<-veCLL:16785.1146, KL:2.4759, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3889, |w|: 23.2721, |dw|: 1.0000, |w_opt|: 0.1656>>
# 	<<-veCLL:16775.3074, KL:2.5534, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4060, |w|: 23.1877, |dw|: 1.0000, |w_opt|: 0.1882>>
# 	<<-veCLL:16809.3027, KL:2.7315, anneal:1.0000>>
# 	<<(Ep 13) Bound: 8.4193 [Took 29.9863 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.3765, |w|: 23.0939, |dw|: 1.0000, |w_opt|: 0.2253>>
# 	<<-veCLL:16750.4137, KL:2.6151, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4261, |w|: 23.0068, |dw|: 1.0000, |w_opt|: 0.1791>>
# 	<<-veCLL:16849.2253, KL:2.8931, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4397, |w|: 22.9219, |dw|: 1.0000, |w_opt|: 0.2633>>
# 	<<-veCLL:16876.7191, KL:2.7646, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4424, |w|: 22.8462, |dw|: 1.0000, |w_opt|: 0.2245>>
# 	<<-veCLL:16881.8770, KL:2.9534, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4437, |w|: 22.7547, |dw|: 1.0000, |w_opt|: 0.2012>>
# 	<<-veCLL:16884.4740, KL:2.9639, anneal:1.0000>>
# 	<<(Ep 14) Bound: 8.4194 [Took 29.7241 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4159, |w|: 22.6771, |dw|: 1.0000, |w_opt|: 0.2754>>
# 	<<-veCLL:16827.6210, KL:4.2574, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.3691, |w|: 22.5941, |dw|: 1.0000, |w_opt|: 0.2559>>
# 	<<-veCLL:16734.9696, KL:3.2925, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4438, |w|: 22.5087, |dw|: 1.0000, |w_opt|: 0.1799>>
# 	<<-veCLL:16883.8910, KL:3.7541, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4161, |w|: 22.4298, |dw|: 1.0000, |w_opt|: 0.1640>>
# 	<<-veCLL:16828.7140, KL:3.5259, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4619, |w|: 22.3518, |dw|: 1.0000, |w_opt|: 0.1451>>
# 	<<-veCLL:16920.2946, KL:3.4263, anneal:1.0000>>
# 	<<(Ep 15) Bound: 8.4194 [Took 29.8710 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.3943, |w|: 22.2740, |dw|: 1.0000, |w_opt|: 0.1903>>
# 	<<-veCLL:16785.2562, KL:3.3982, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4443, |w|: 22.1962, |dw|: 1.0000, |w_opt|: 0.1849>>
# 	<<-veCLL:16886.2202, KL:2.2942, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4129, |w|: 22.1277, |dw|: 1.0000, |w_opt|: 0.1051>>
# 	<<-veCLL:16823.5550, KL:2.2875, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3739, |w|: 22.0567, |dw|: 1.0000, |w_opt|: 0.1165>>
# 	<<-veCLL:16745.3709, KL:2.4270, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3844, |w|: 21.9763, |dw|: 1.0000, |w_opt|: 0.1731>>
# 	<<-veCLL:16766.2572, KL:2.4633, anneal:1.0000>>
# 	<<(Ep 16) Bound: 8.4196 [Took 29.6998 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4039, |w|: 21.8939, |dw|: 1.0000, |w_opt|: 0.1170>>
# 	<<-veCLL:16806.0614, KL:1.8338, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4668, |w|: 21.8133, |dw|: 1.0000, |w_opt|: 0.1830>>
# 	<<-veCLL:16931.9732, KL:1.5419, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4244, |w|: 21.7368, |dw|: 1.0000, |w_opt|: 0.1475>>
# 	<<-veCLL:16847.2396, KL:1.5688, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3947, |w|: 21.6565, |dw|: 1.0000, |w_opt|: 0.1075>>
# 	<<-veCLL:16787.8448, KL:1.6259, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3614, |w|: 21.5722, |dw|: 1.0000, |w_opt|: 0.2118>>
# 	<<-veCLL:16721.2472, KL:1.6420, anneal:1.0000>>
# 	<<(Ep 17) Bound: 8.4193 [Took 29.7461 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.3932, |w|: 21.4904, |dw|: 1.0000, |w_opt|: 0.1670>>
# 	<<-veCLL:16784.3695, KL:2.1290, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.3792, |w|: 21.4154, |dw|: 1.0000, |w_opt|: 0.1073>>
# 	<<-veCLL:16756.5780, KL:1.7234, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4072, |w|: 21.3424, |dw|: 1.0000, |w_opt|: 0.2361>>
# 	<<-veCLL:16813.1755, KL:1.2208, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4077, |w|: 21.2702, |dw|: 1.0000, |w_opt|: 0.2510>>
# 	<<-veCLL:16813.9038, KL:1.5143, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3599, |w|: 21.1951, |dw|: 1.0000, |w_opt|: 0.1939>>
# 	<<-veCLL:16717.9656, KL:1.9339, anneal:1.0000>>
# 	<<(Ep 18) Bound: 8.4194 [Took 29.7278 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4424, |w|: 21.1274, |dw|: 1.0000, |w_opt|: 0.1846>>
# 	<<-veCLL:16882.9713, KL:1.7373, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4488, |w|: 21.0499, |dw|: 1.0000, |w_opt|: 0.1342>>
# 	<<-veCLL:16896.1416, KL:1.4843, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4385, |w|: 20.9798, |dw|: 1.0000, |w_opt|: 0.2530>>
# 	<<-veCLL:16875.6027, KL:1.2996, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3753, |w|: 20.9081, |dw|: 1.0000, |w_opt|: 0.2048>>
# 	<<-veCLL:16749.6511, KL:0.9150, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4586, |w|: 20.8394, |dw|: 1.0000, |w_opt|: 0.1766>>
# 	<<-veCLL:16916.1575, KL:0.9794, anneal:1.0000>>
# 	<<(Ep 19) Bound: 8.4195 [Took 29.6770 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4314, |w|: 20.7675, |dw|: 1.0000, |w_opt|: 0.1334>>
# 	<<-veCLL:16861.9071, KL:0.8405, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4349, |w|: 20.6902, |dw|: 1.0000, |w_opt|: 0.2205>>
# 	<<-veCLL:16868.9361, KL:0.8861, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.3799, |w|: 20.6300, |dw|: 1.0000, |w_opt|: 0.1510>>
# 	<<-veCLL:16758.9612, KL:0.8478, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3745, |w|: 20.5594, |dw|: 1.0000, |w_opt|: 0.2030>>
# 	<<-veCLL:16748.1018, KL:0.8533, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4551, |w|: 20.4949, |dw|: 1.0000, |w_opt|: 0.1542>>
# 	<<-veCLL:16909.3038, KL:0.9513, anneal:1.0000>>
# 	<<(Ep 20) Bound: 8.4193 [Took 29.7372 seconds] >>
# 	<<Saving at epoch 20>>
# 	<<Saved model (./chkpt-ipython/DMM_lr-0_0008-dh-40-ds-2-nl-relu-bs-200-ep-40-rs-80-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid-EP20-params)
# 		 opt (./chkpt-ipython/DMM_lr-0_0008-dh-40-ds-2-nl-relu-bs-200-ep-40-rs-80-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid-EP20-optParams) weights>>
# 	<<Original dim: [10000    10     3],[10000    10]>>
# 	<<New dim: [1000   10    3],[1000   10]>>
# 	<<(Evaluate) Validation Bound: 8.4422 [Took 0.3430 seconds]>>
# 	<<Original dim: [1000   10    3],[1000   10]>>
# 	<<New dim: [10000    10     3],[10000    10]>>
# 	<<Bnum: 0, Batch Bound: 8.3972, |w|: 20.4241, |dw|: 1.0000, |w_opt|: 0.2152>>
# 	<<-veCLL:16793.4373, KL:0.9505, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.3868, |w|: 20.3532, |dw|: 1.0000, |w_opt|: 0.2937>>
# 	<<-veCLL:16772.5981, KL:0.9385, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4310, |w|: 20.2937, |dw|: 1.0000, |w_opt|: 0.2119>>
# 	<<-veCLL:16861.0963, KL:0.9564, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4399, |w|: 20.2312, |dw|: 1.0000, |w_opt|: 0.1558>>
# 	<<-veCLL:16878.8254, KL:1.0102, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3907, |w|: 20.1792, |dw|: 1.0000, |w_opt|: 0.2253>>
# 	<<-veCLL:16780.3847, KL:1.0743, anneal:1.0000>>
# 	<<(Ep 21) Bound: 8.4194 [Took 29.3487 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.3710, |w|: 20.1247, |dw|: 1.0000, |w_opt|: 0.2653>>
# 	<<-veCLL:16740.9422, KL:1.0486, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4677, |w|: 20.0625, |dw|: 1.0000, |w_opt|: 0.2189>>
# 	<<-veCLL:16934.1749, KL:1.1973, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4140, |w|: 19.9976, |dw|: 1.0000, |w_opt|: 0.1635>>
# 	<<-veCLL:16826.9911, KL:0.9237, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3929, |w|: 19.9321, |dw|: 1.0000, |w_opt|: 0.1561>>
# 	<<-veCLL:16785.0535, KL:0.7293, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4018, |w|: 19.8778, |dw|: 1.0000, |w_opt|: 0.1680>>
# 	<<-veCLL:16802.8982, KL:0.6384, anneal:1.0000>>
# 	<<(Ep 22) Bound: 8.4192 [Took 29.4806 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4333, |w|: 19.8184, |dw|: 1.0000, |w_opt|: 0.2297>>
# 	<<-veCLL:16866.0027, KL:0.6391, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.3990, |w|: 19.7552, |dw|: 1.0000, |w_opt|: 0.2493>>
# 	<<-veCLL:16797.2184, KL:0.6820, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4263, |w|: 19.6889, |dw|: 1.0000, |w_opt|: 0.2275>>
# 	<<-veCLL:16851.8443, KL:0.6739, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4293, |w|: 19.6253, |dw|: 1.0000, |w_opt|: 0.2099>>
# 	<<-veCLL:16857.9763, KL:0.6376, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4849, |w|: 19.5610, |dw|: 1.0000, |w_opt|: 0.2144>>
# 	<<-veCLL:16968.9723, KL:0.7700, anneal:1.0000>>
# 	<<(Ep 23) Bound: 8.4192 [Took 29.4176 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4020, |w|: 19.4915, |dw|: 1.0000, |w_opt|: 0.2316>>
# 	<<-veCLL:16803.3570, KL:0.6766, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.3954, |w|: 19.4246, |dw|: 1.0000, |w_opt|: 0.1890>>
# 	<<-veCLL:16790.1816, KL:0.6150, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4034, |w|: 19.3672, |dw|: 1.0000, |w_opt|: 0.2158>>
# 	<<-veCLL:16806.1460, KL:0.6235, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4489, |w|: 19.3082, |dw|: 1.0000, |w_opt|: 0.2098>>
# 	<<-veCLL:16897.1106, KL:0.6542, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4167, |w|: 19.2364, |dw|: 1.0000, |w_opt|: 0.3239>>
# 	<<-veCLL:16832.5616, KL:0.8475, anneal:1.0000>>
# 	<<(Ep 24) Bound: 8.4191 [Took 29.9143 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4199, |w|: 19.1722, |dw|: 1.0000, |w_opt|: 0.1529>>
# 	<<-veCLL:16838.9584, KL:0.8561, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4403, |w|: 19.1066, |dw|: 1.0000, |w_opt|: 0.1545>>
# 	<<-veCLL:16879.9457, KL:0.6503, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.3959, |w|: 19.0457, |dw|: 1.0000, |w_opt|: 0.2514>>
# 	<<-veCLL:16791.1341, KL:0.5735, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4343, |w|: 18.9869, |dw|: 1.0000, |w_opt|: 0.1821>>
# 	<<-veCLL:16868.0402, KL:0.5808, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3967, |w|: 18.9260, |dw|: 1.0000, |w_opt|: 0.2157>>
# 	<<-veCLL:16792.7112, KL:0.6703, anneal:1.0000>>
# 	<<(Ep 25) Bound: 8.4193 [Took 29.3256 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4299, |w|: 18.8641, |dw|: 1.0000, |w_opt|: 0.1914>>
# 	<<-veCLL:16859.2041, KL:0.5523, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4436, |w|: 18.7988, |dw|: 1.0000, |w_opt|: 0.1728>>
# 	<<-veCLL:16886.6408, KL:0.5630, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4041, |w|: 18.7474, |dw|: 1.0000, |w_opt|: 0.1881>>
# 	<<-veCLL:16807.4672, KL:0.6771, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3802, |w|: 18.6898, |dw|: 1.0000, |w_opt|: 0.2448>>
# 	<<-veCLL:16759.8627, KL:0.5163, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4055, |w|: 18.6271, |dw|: 1.0000, |w_opt|: 0.2712>>
# 	<<-veCLL:16810.3515, KL:0.5976, anneal:1.0000>>
# 	<<(Ep 26) Bound: 8.4192 [Took 30.0049 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4106, |w|: 18.5585, |dw|: 1.0000, |w_opt|: 0.2496>>
# 	<<-veCLL:16820.6007, KL:0.5508, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4394, |w|: 18.4941, |dw|: 1.0000, |w_opt|: 0.1664>>
# 	<<-veCLL:16878.1981, KL:0.5939, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4226, |w|: 18.4400, |dw|: 1.0000, |w_opt|: 0.2484>>
# 	<<-veCLL:16844.4589, KL:0.6854, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4328, |w|: 18.3849, |dw|: 1.0000, |w_opt|: 0.1911>>
# 	<<-veCLL:16864.7786, KL:0.7464, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3780, |w|: 18.3293, |dw|: 1.0000, |w_opt|: 0.2211>>
# 	<<-veCLL:16755.4725, KL:0.5557, anneal:1.0000>>
# 	<<(Ep 27) Bound: 8.4192 [Took 29.2922 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4681, |w|: 18.2765, |dw|: 1.0000, |w_opt|: 0.1912>>
# 	<<-veCLL:16935.7056, KL:0.5442, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4075, |w|: 18.2098, |dw|: 1.0000, |w_opt|: 0.1909>>
# 	<<-veCLL:16814.4608, KL:0.4724, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.3946, |w|: 18.1450, |dw|: 1.0000, |w_opt|: 0.2258>>
# 	<<-veCLL:16788.7558, KL:0.3582, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4501, |w|: 18.0930, |dw|: 1.0000, |w_opt|: 0.2586>>
# 	<<-veCLL:16899.8486, KL:0.3978, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4173, |w|: 18.0310, |dw|: 1.0000, |w_opt|: 0.0945>>
# 	<<-veCLL:16834.2653, KL:0.4085, anneal:1.0000>>
# 	<<(Ep 28) Bound: 8.4195 [Took 29.3688 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4417, |w|: 17.9864, |dw|: 1.0000, |w_opt|: 0.1413>>
# 	<<-veCLL:16882.9510, KL:0.4255, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4282, |w|: 17.9302, |dw|: 1.0000, |w_opt|: 0.2039>>
# 	<<-veCLL:16855.9718, KL:0.3818, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4618, |w|: 17.8772, |dw|: 1.0000, |w_opt|: 0.1519>>
# 	<<-veCLL:16923.1698, KL:0.3964, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4171, |w|: 17.8195, |dw|: 1.0000, |w_opt|: 0.3084>>
# 	<<-veCLL:16833.8290, KL:0.4440, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4047, |w|: 17.7736, |dw|: 1.0000, |w_opt|: 0.1655>>
# 	<<-veCLL:16808.9499, KL:0.4296, anneal:1.0000>>
# 	<<(Ep 29) Bound: 8.4192 [Took 29.1667 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4643, |w|: 17.7098, |dw|: 1.0000, |w_opt|: 0.1793>>
# 	<<-veCLL:16928.1344, KL:0.4087, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4376, |w|: 17.6527, |dw|: 1.0000, |w_opt|: 0.2514>>
# 	<<-veCLL:16874.7190, KL:0.4412, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4197, |w|: 17.5984, |dw|: 1.0000, |w_opt|: 0.1597>>
# 	<<-veCLL:16839.0196, KL:0.4113, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4055, |w|: 17.5317, |dw|: 1.0000, |w_opt|: 0.1595>>
# 	<<-veCLL:16810.6951, KL:0.3331, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4415, |w|: 17.4714, |dw|: 1.0000, |w_opt|: 0.1716>>
# 	<<-veCLL:16882.6732, KL:0.2926, anneal:1.0000>>
# 	<<(Ep 30) Bound: 8.4192 [Took 29.1580 seconds] >>
# 	<<Saving at epoch 30>>
# 	<<Saved model (./chkpt-ipython/DMM_lr-0_0008-dh-40-ds-2-nl-relu-bs-200-ep-40-rs-80-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid-EP30-params)
# 		 opt (./chkpt-ipython/DMM_lr-0_0008-dh-40-ds-2-nl-relu-bs-200-ep-40-rs-80-rd-0_1-infm-R-tl-2-el-2-ar-2_0-use_p-approx-rc-lstm-uid-EP30-optParams) weights>>
# 	<<Original dim: [10000    10     3],[10000    10]>>
# 	<<New dim: [1000   10    3],[1000   10]>>
# 	<<(Evaluate) Validation Bound: 8.4422 [Took 0.3394 seconds]>>
# 	<<Original dim: [1000   10    3],[1000   10]>>
# 	<<New dim: [10000    10     3],[10000    10]>>
# 	<<Bnum: 0, Batch Bound: 8.4155, |w|: 17.4227, |dw|: 1.0000, |w_opt|: 0.2292>>
# 	<<-veCLL:16830.8108, KL:0.2834, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.3987, |w|: 17.3736, |dw|: 1.0000, |w_opt|: 0.2182>>
# 	<<-veCLL:16797.0598, KL:0.2614, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4504, |w|: 17.3182, |dw|: 1.0000, |w_opt|: 0.1583>>
# 	<<-veCLL:16900.5043, KL:0.2844, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4365, |w|: 17.2659, |dw|: 1.0000, |w_opt|: 0.2244>>
# 	<<-veCLL:16872.6314, KL:0.3144, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3968, |w|: 17.2087, |dw|: 1.0000, |w_opt|: 0.1869>>
# 	<<-veCLL:16793.3919, KL:0.3051, anneal:1.0000>>
# 	<<(Ep 31) Bound: 8.4192 [Took 30.0698 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4469, |w|: 17.1629, |dw|: 1.0000, |w_opt|: 0.1927>>
# 	<<-veCLL:16893.4484, KL:0.3099, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4513, |w|: 17.1090, |dw|: 1.0000, |w_opt|: 0.2041>>
# 	<<-veCLL:16902.2531, KL:0.2987, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4134, |w|: 17.0702, |dw|: 1.0000, |w_opt|: 0.2974>>
# 	<<-veCLL:16826.5506, KL:0.2643, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4080, |w|: 17.0287, |dw|: 1.0000, |w_opt|: 0.2540>>
# 	<<-veCLL:16815.7189, KL:0.2525, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4332, |w|: 16.9841, |dw|: 1.0000, |w_opt|: 0.1617>>
# 	<<-veCLL:16866.1896, KL:0.2610, anneal:1.0000>>
# 	<<(Ep 32) Bound: 8.4194 [Took 29.4038 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4402, |w|: 16.9389, |dw|: 1.0000, |w_opt|: 0.1509>>
# 	<<-veCLL:16880.2111, KL:0.2747, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4390, |w|: 16.8859, |dw|: 1.0000, |w_opt|: 0.1400>>
# 	<<-veCLL:16877.7255, KL:0.3166, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4391, |w|: 16.8454, |dw|: 1.0000, |w_opt|: 0.2406>>
# 	<<-veCLL:16877.8553, KL:0.3688, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3594, |w|: 16.7965, |dw|: 1.0000, |w_opt|: 0.2576>>
# 	<<-veCLL:16718.3194, KL:0.4103, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4690, |w|: 16.7523, |dw|: 1.0000, |w_opt|: 0.1615>>
# 	<<-veCLL:16937.5778, KL:0.5047, anneal:1.0000>>
# 	<<(Ep 33) Bound: 8.4190 [Took 29.3563 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4528, |w|: 16.7029, |dw|: 1.0000, |w_opt|: 0.2026>>
# 	<<-veCLL:16905.1528, KL:0.3863, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4113, |w|: 16.6460, |dw|: 1.0000, |w_opt|: 0.2537>>
# 	<<-veCLL:16822.0751, KL:0.4367, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.3864, |w|: 16.6098, |dw|: 1.0000, |w_opt|: 0.1660>>
# 	<<-veCLL:16772.3152, KL:0.5688, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4148, |w|: 16.5530, |dw|: 1.0000, |w_opt|: 0.1985>>
# 	<<-veCLL:16829.0560, KL:0.4830, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3785, |w|: 16.5093, |dw|: 1.0000, |w_opt|: 0.2760>>
# 	<<-veCLL:16756.5932, KL:0.3587, anneal:1.0000>>
# 	<<(Ep 34) Bound: 8.4196 [Took 29.3923 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.3959, |w|: 16.4645, |dw|: 1.0000, |w_opt|: 0.2450>>
# 	<<-veCLL:16791.5111, KL:0.3720, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.3833, |w|: 16.4178, |dw|: 1.0000, |w_opt|: 0.1019>>
# 	<<-veCLL:16766.3661, KL:0.2910, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4079, |w|: 16.3655, |dw|: 1.0000, |w_opt|: 0.1834>>
# 	<<-veCLL:16815.4607, KL:0.2520, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.3969, |w|: 16.3237, |dw|: 1.0000, |w_opt|: 0.2274>>
# 	<<-veCLL:16793.5726, KL:0.2470, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4062, |w|: 16.2766, |dw|: 1.0000, |w_opt|: 0.1539>>
# 	<<-veCLL:16812.0560, KL:0.3001, anneal:1.0000>>
# 	<<(Ep 35) Bound: 8.4192 [Took 29.4995 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4363, |w|: 16.2242, |dw|: 1.0000, |w_opt|: 0.1511>>
# 	<<-veCLL:16872.3738, KL:0.3156, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4352, |w|: 16.1806, |dw|: 1.0000, |w_opt|: 0.1758>>
# 	<<-veCLL:16870.0481, KL:0.3301, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4019, |w|: 16.1363, |dw|: 1.0000, |w_opt|: 0.1653>>
# 	<<-veCLL:16803.4453, KL:0.3894, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4108, |w|: 16.0837, |dw|: 1.0000, |w_opt|: 0.1481>>
# 	<<-veCLL:16821.2417, KL:0.3669, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4080, |w|: 16.0332, |dw|: 1.0000, |w_opt|: 0.1872>>
# 	<<-veCLL:16815.6475, KL:0.3282, anneal:1.0000>>
# 	<<(Ep 36) Bound: 8.4191 [Took 29.5791 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.3859, |w|: 15.9853, |dw|: 1.0000, |w_opt|: 0.2037>>
# 	<<-veCLL:16771.3039, KL:0.4104, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4285, |w|: 15.9380, |dw|: 1.0000, |w_opt|: 0.2248>>
# 	<<-veCLL:16856.5479, KL:0.4350, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4396, |w|: 15.8815, |dw|: 1.0000, |w_opt|: 0.1673>>
# 	<<-veCLL:16878.8409, KL:0.3485, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4171, |w|: 15.8435, |dw|: 1.0000, |w_opt|: 0.1998>>
# 	<<-veCLL:16833.8731, KL:0.3458, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.4233, |w|: 15.8003, |dw|: 1.0000, |w_opt|: 0.1778>>
# 	<<-veCLL:16846.1476, KL:0.4107, anneal:1.0000>>
# 	<<(Ep 37) Bound: 8.4191 [Took 30.1257 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4425, |w|: 15.7521, |dw|: 1.0000, |w_opt|: 0.1738>>
# 	<<-veCLL:16884.5795, KL:0.4650, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4366, |w|: 15.7085, |dw|: 1.0000, |w_opt|: 0.1619>>
# 	<<-veCLL:16872.7296, KL:0.4814, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4236, |w|: 15.6565, |dw|: 1.0000, |w_opt|: 0.2387>>
# 	<<-veCLL:16846.8190, KL:0.4057, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4083, |w|: 15.6134, |dw|: 1.0000, |w_opt|: 0.2340>>
# 	<<-veCLL:16816.2244, KL:0.4286, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3797, |w|: 15.5661, |dw|: 1.0000, |w_opt|: 0.1540>>
# 	<<-veCLL:16758.8965, KL:0.4140, anneal:1.0000>>
# 	<<(Ep 38) Bound: 8.4190 [Took 30.3132 seconds] >>
# 	<<Bnum: 0, Batch Bound: 8.4049, |w|: 15.5169, |dw|: 1.0000, |w_opt|: 0.1308>>
# 	<<-veCLL:16809.4179, KL:0.4219, anneal:1.0000>>
# 	<<Bnum: 10, Batch Bound: 8.4001, |w|: 15.4739, |dw|: 1.0000, |w_opt|: 0.2484>>
# 	<<-veCLL:16799.6340, KL:0.5238, anneal:1.0000>>
# 	<<Bnum: 20, Batch Bound: 8.4518, |w|: 15.4257, |dw|: 1.0000, |w_opt|: 0.1166>>
# 	<<-veCLL:16903.0700, KL:0.5592, anneal:1.0000>>
# 	<<Bnum: 30, Batch Bound: 8.4524, |w|: 15.3964, |dw|: 1.0000, |w_opt|: 0.1855>>
# 	<<-veCLL:16904.1647, KL:0.7146, anneal:1.0000>>
# 	<<Bnum: 40, Batch Bound: 8.3983, |w|: 15.3500, |dw|: 1.0000, |w_opt|: 0.1478>>
# 	<<-veCLL:16796.0828, KL:0.5776, anneal:1.0000>>
# 	<<(Ep 39) Bound: 8.4191 [Took 30.4280 seconds] >>
